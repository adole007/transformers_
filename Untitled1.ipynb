# %%
#link database server to python
import mysql.connector
import pyodbc

#install packages
import numpy as np
import pandas as pd
import streamlit as st 
#import plotly.express as px

import pandas as pd
import numpy as np
  
# %matplotlib inline
from plotly import __version__
import cufflinks as cf
  
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px

# to get the connection
init_notebook_mode(connected = True)
  
# plotly also serves online,
# but we are using just a sample
cf.go_offline()

import time as t 
import matplotlib.pyplot as plt
import time # to simulate a real 


##Basic dashboard configuration 
st.set_page_config(
    page_title="Analysing the Vieunite App",
    page_icon="✅",
    layout="wide",
)

##connect to the database server
# Creating connection object
mydb = mysql.connector.connect(
    host = "54.74.218.221",
    user = "vieunite",
    password = "Allsee2022!",
    database = "vieunite"
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
query_user = "SELECT * FROM pframe_user;" 
d_f = pd.read_sql(query_user, mydb)
#print(df.head())
daf=pd.DataFrame(d_f)
        
@st.experimental_memo()
def get_data() -> pd.DataFrame:
    return daf
df_user = get_data()

# %%
if df_user['status'].values == 1:
    df_user['status'].value_counts().1
else:
    df_user['status'].value_counts().2

# %%
query_order_g = "SELECT * FROM pframe_order_goods;" 
query_artwork =  "SELECT * FROM pframe_artwork;"
artwork_g = pd.read_sql(query_artwork,mydb)
order_g = pd.read_sql(query_order_g, mydb)
#print(df.head())
daf_query_order_g=pd.DataFrame(order_g)
daf_query_artwork = pd.DataFrame(artwork_g)

# %%
df_user.status.value_counts()[1]

# %%
df_user['status'].value_counts()

# %%
#daf_query_order_g.groupby('artwork_id')['num']
#daf_query_artwork.head()

# %%
daf_query_order_g.head()
# Out:
#                      id             order_id  \
# 0  14632217321312232311   146322173213125454
# 1  14632217321312232324   146322173213123222
# 2  14632217321312232352   146322173213123222
# 3   1470213009863446529  1470213009699868673
# 4   1470227958522257409  1470227958388039681
#
#                          artwork_id  num    price   amount  \
# 0               1465121706105356290    1  10000.0  10000.0
# 1  91decac68377427281b8df2375015fbb    1   2000.0   2000.0
# 2  91decac68377427281b8df2375015fcc    1   2000.0   2000.0
# 3               1465121706105356290    2     10.0     20.0
# 4               1464064526610489345    1    100.0    100.0
#
#           create_time  del_flag
# 0 2021-11-15 17:11:42         0
# 1 2021-11-15 17:00:42         0
# 2 2021-11-15 17:10:42         0
# 3 2021-12-13 10:04:31         0
# 4 2021-12-13 11:03:55         0

# %%
#daf_query_order_g.groupby('num')['artwork_id'].values()
daf_query_order_g
# Out:
#                        id             order_id  \
# 0    14632217321312232311   146322173213125454
# 1    14632217321312232324   146322173213123222
# 2    14632217321312232352   146322173213123222
# 3     1470213009863446529  1470213009699868673
# 4     1470227958522257409  1470227958388039681
# ..                    ...                  ...
# 124   1499799249616896002  1499799249486872578
# 125   1500014790067699713  1500014789908316162
# 126   1500014936474075138  1500014936327274498
# 127   1500649877092286466  1500649876274397186
# 128   1500667451410595841  1500667450617872385
#
#                            artwork_id  num    price   amount  \
# 0                 1465121706105356290    1  10000.0  10000.0
# 1    91decac68377427281b8df2375015fbb    1   2000.0   2000.0
# 2    91decac68377427281b8df2375015fcc    1   2000.0   2000.0
# 3                 1465121706105356290    2     10.0     20.0
# 4                 1464064526610489345    1    100.0    100.0
# ...

# %%
daf_query_order_g.sort_values(by='num', ascending = False)[:20]
# Out:
#                       id             order_id           artwork_id  num  \
# 13   1472036562904555521  1472036562774532098  1465124902848577538    2
# 8    1470285582907273218  1470285581846114305  1465121706105356290    2
# 45   1472765306967539713  1472765306791378945  1465121706105356290    2
# 15   1472037278817722370  1472037278687698945  1465121706105356290    2
# 14   1472036651555364865  1472036651429535745  1465124902848577538    2
# 12   1472036189003325441  1472036188860719106  1465124902848577538    2
# 11   1472026503243997185  1472026503084613634  1465121706105356290    2
# 10   1471668582836424705  1471668582677041153  1465121706105356290    2
# 9    1471662258459328514  1471662258299944962  1465121706105356290    2
# 7    1470283224706048002  1470283224580218882  1465121706105356290    2
# 6    1470283011903840258  1470283011744456705  1465121706105356290    2
# 38   1472745542618517506  1472745542480105473  1465124327297810434    2
# ...

# %%
fig = px.pie(daf_query_order_g, values = 'num',names ='artwork_id',
             title = 'Ranking Artwork Purchase by Users',
             hover_data = ['price','amount'])
#fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>
#
#
#             <div id="cf3e9131-af84-4e5c-939f-0ae914f63ae8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf3e9131-af84-4e5c-939f-0ae914f63ae8")) {
#                     Plotly.newPlot(
#                         'cf3e9131-af84-4e5c-939f-0ae914f63ae8',
# ...

# %%
fig = px.pie(user_order_goods_artwork, values = 'num',names ='username',hover_data = ['price_x','amount'])
#fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>
#
#
#             <div id="93ba685e-9461-4a46-bb0a-d1d90843fd38" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93ba685e-9461-4a46-bb0a-d1d90843fd38")) {
#                     Plotly.newPlot(
#                         '93ba685e-9461-4a46-bb0a-d1d90843fd38',
# ...

# %%
#daf #pframe_user
#daf_query_order_g #pframe_order_goods
#daf_query_artwork #pframe_artwork
order_goods_artwork=daf_query_order_g.merge(daf_query_artwork, how='inner', left_on='artwork_id', right_on='id')
user_order_goods_artwork=order_goods_artwork.merge(daf, how='inner', left_on='user_id', right_on='id')
user_order_goods_artwork.columns
# Out:
# Index(['id_x', 'order_id', 'artwork_id', 'num', 'price_x', 'amount',
#        'create_time_x', 'del_flag_x', 'id_y', 'user_id', 'artist_id',
#        'artwork_category_id', 'type', 'name', 'pic_url', 'cost_price',
#        'price_y', 'stock', 'display_type', 'author', 'introduce', 'is_free',
#        'views_num', 'create_time_y', 'del_flag_y', 'praise_total',
#        'forward_total', 'comment_total', 'status_x', 'reason', 'updown_status',
#        'pic_width', 'pic_height', 'mark_id', 'power_type', 'resource_type',
#        'user_store_id', 'id', 'username', 'user_type', 'realname', 'nickname',
#        'password', 'salt', 'is_auth', 'avatar', 'birthday', 'sex', 'email',
#        'phone', 'status_y', 'del_flag', 'praise_num', 'fans_num', 'follow_num',
#        'balance', 'pay_password', 'create_time', 'update_time',
#        'background_url', 'info'],
#       dtype='object')

# %%
order_goods_artwork.head(8)
# Out:
#                    id_x             order_id           artwork_id  num  \
# 0  14632217321312232311   146322173213125454  1465121706105356290    1
# 1   1470213009863446529  1470213009699868673  1465121706105356290    2
# 2   1470283011903840258  1470283011744456705  1465121706105356290    2
# 3   1470283224706048002  1470283224580218882  1465121706105356290    2
# 4   1470285582907273218  1470285581846114305  1465121706105356290    2
# 5   1471662258459328514  1471662258299944962  1465121706105356290    2
# 6   1471668582836424705  1471668582677041153  1465121706105356290    2
# 7   1472026503243997185  1472026503084613634  1465121706105356290    2
#
#    price_x   amount       create_time_x  del_flag_x                 id_y  \
# 0  10000.0  10000.0 2021-11-15 17:11:42           0  1465121706105356290
# 1     10.0     20.0 2021-12-13 10:04:31           0  1465121706105356290
# 2     10.0     20.0 2021-12-13 14:42:41           0  1465121706105356290
# ...

# %%
cd =daf_query_order_g.sort_values(by='num', ascending = False)[:20] #sort in other of number of purchase

# %%
query_user_browse = "SELECT * FROM pframe_user_browse_image_log;" 

user_browse_g = pd.read_sql(query_user_browse,mydb)

#print(df.head())
daf_query_user_browse_g=pd.DataFrame(user_browse_g)

# %%
daf_query_user_browse_g.sort_values(by ='image_id') #daf_query_artwork
# Out:
#                       id              user_id  \
# 213  1501057671171739649  1463407248797724674
# 162  1499801403094204417  1496515177994096642
# 161  1499801097652404226  1496515177994096642
# 160  1499800837374869506  1496515177994096642
# 159  1499800528405659649  1496515177994096642
# ..                   ...                  ...
# 194  1500027364939218945  1463407248797724674
# 203  1500736933785092097  1500710544298065921
# 204  1500736999199457281  1500710544298065921
# 205  1500737359221735425  1500710544298065921
# 121  1499320719380692994  1463407248797724674
#
#                              image_id          click_time  view_time
# 213               1464064526610489345 2022-03-08 12:50:12          0
# 162               1464064526610489345 2022-03-05 01:38:14          0
# 161               1464064526610489345 2022-03-05 01:37:01          0
# 160               1464064526610489345 2022-03-05 01:35:59          0
# ...

# %%
ds=daf_query_user_browse_g.merge(daf_query_artwork, how='inner', left_on='image_id', right_on='id')

# %%
ds.head()
#ds.columns
# Out:
#                   id_x            user_id_x             image_id  \
# 0  1493436370810671106  1460432812046774274  1464073752850411521
# 1  1497191659137503234  1496515635844321281  1464073752850411521
# 2  1497192581431398401  1496515635844321281  1464073752850411521
# 3  1497220622467567617  1496515177994096642  1464073752850411521
# 4  1498500619077521409  1463330641890349057  1464073752850411521
#
#            click_time  view_time                 id_y            user_id_y  \
# 0 2022-02-15 12:05:52          0  1464073752850411521  1463036805796450305
# 1 2022-02-25 20:48:03          0  1464073752850411521  1463036805796450305
# 2 2022-02-25 20:51:43          0  1464073752850411521  1463036805796450305
# 3 2022-02-25 22:43:08          0  1464073752850411521  1463036805796450305
# 4 2022-03-01 11:29:23          0  1464073752850411521  1463036805796450305
#
#              artist_id  artwork_category_id  type  ... comment_total status  \
# ...

# %%
fig = px.pie(daf_query_user_browse_g.merge(daf_query_artwork, how='inner', left_on='image_id', right_on='id'), values = 'image_id',names ='name',
             title = 'Ranking of Artwork views by user',
             hover_data = ['id_y','image_id'])
#fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>
#
#
#             <div id="7e564cfa-063b-4d61-a691-6d00b2d43cf7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e564cfa-063b-4d61-a691-6d00b2d43cf7")) {
#                     Plotly.newPlot(
#                         '7e564cfa-063b-4d61-a691-6d00b2d43cf7',
# ...

# %%
#daf_query_user_browse_g
#daf_query_artwork
query_artwork_category = "SELECT * FROM pframe_artwork_category;" 

artwork_category_g = pd.read_sql(query_artwork_category,mydb)

#print(df.head())
daf_query_artwork_category_g=pd.DataFrame(artwork_category_g)

# %%
daf_query_artwork_category_g
# Out:
#                           id                   name  del_flag  is_enable
# 0   13a2137ad1281237ayte12z3                   名山大川         0          0
# 1        1464096191122710530                    保守派         0          1
# 2        1464096407078993921                  测试类别2         0          0
# 3        1481493759757803522  Abstractionist school         0          1
# 4        1481494075219795969            Romanticism         0          1
# 5        1481525845277634562                     11         0          1
# 6        1481525917411274754                   2222         0          1
# 7        1481525963083051010                    111         0          1
# 8        1481527062582095873                     22         0          0
# 9        1481811179416666114                   测试按钮         0          1
# 10  dd12137ad1281237ayte12aj                   梅兰竹菊         0          1

# %%
user_browse_g_artwork=daf_query_user_browse_g.merge(daf_query_artwork, how='inner', left_on='image_id', right_on='id')
user_order_goods_artwork=user_browse_g_artwork.merge(daf_query_artwork_category_g, how='inner', left_on='artwork_category_id', right_on='id')
user_order_goods_artwork.columns
# Out:
# Index(['id_x', 'user_id_x', 'image_id', 'click_time', 'view_time', 'id_y',
#        'user_id_y', 'artist_id', 'artwork_category_id', 'type', 'name_x',
#        'pic_url', 'cost_price', 'price', 'stock', 'display_type', 'author',
#        'introduce', 'is_free', 'views_num', 'create_time', 'del_flag_x',
#        'praise_total', 'forward_total', 'comment_total', 'status', 'reason',
#        'updown_status', 'pic_width', 'pic_height', 'mark_id', 'power_type',
#        'resource_type', 'user_store_id', 'id', 'name_y', 'del_flag_y',
#        'is_enable'],
#       dtype='object')

# %%
user_order_goods_artwork.name_y
# Out:
# 0                        保守派
# 1                        保守派
# 2                        保守派
# 3                        保守派
# 4                        保守派
#                ...
# 209                     名山大川
# 210                     梅兰竹菊
# 211    Abstractionist school
# 212    Abstractionist school
# 213    Abstractionist school
# Name: name_y, Length: 214, dtype: object

# %%
fig=px.histogram(user_order_goods_artwork,y = 'image_id',x ='name_y',color="name_y")
#fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
#fig = px.bar(user_order_goods_artwork, y = 'image_id',x ='name_y',
#             title = 'Artwork Genre most popular with users',
#             hover_data = ['id_y','image_id'])
##fig.update_traces(textposition='inside', textinfo='percent+label')
#fig.show()
# Out:
# <div>
#
#
#             <div id="8ac26910-6464-469c-818e-56ad04763242" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8ac26910-6464-469c-818e-56ad04763242")) {
#                     Plotly.newPlot(
#                         '8ac26910-6464-469c-818e-56ad04763242',
# ...

# %%
fig = px.pie(user_order_goods_artwork,values = 'image_id',names ='name_y')
#             title = 'Artwork Genre most popular with users',
#             hover_data = ['id_y','image_id'])
##fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>
#
#
#             <div id="db4c6b88-da7e-401f-86d8-d24e533831d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db4c6b88-da7e-401f-86d8-d24e533831d1")) {
#                     Plotly.newPlot(
#                         'db4c6b88-da7e-401f-86d8-d24e533831d1',
# ...

# %%
#import os
#import shutil#

#mypath = ...
#for root, dirs, files in os.walk('C:\\Users\\CON3ADOLEA\\Downloads\\wikiart\\wikiart'):
#    for file in files:
#        path_file = os.path.join(root,file)
#        shutil.copy2(path_file,'M:\\VieApp')

# %%
#daf_query_artwork
#daf_query_artwork_category_g


artwork_g_category=daf_query_artwork.merge(daf_query_artwork_category_g, how='inner', left_on='artwork_category_id', right_on='id')
#user_order_goods_artwork=user_browse_g_artwork.merge(daf_query_artwork_category_g, how='inner', left_on='artwork_category_id', right_on='id')
#user_order_goods_artwork.columns

#query_artwork_category = "SELECT * FROM pframe_artwork_category;" 

#artwork_category_g = pd.read_sql(query_artwork_category,mydb)

#print(df.head())
#daf_query_artwork_category_g=pd.DataFrame(artwork_category_g)

# %%
artwork_g_category.columns
# Out:
# Index(['id_x', 'user_id', 'artist_id', 'artwork_category_id', 'type', 'name_x',
#        'pic_url', 'cost_price', 'price', 'stock', 'display_type', 'author',
#        'introduce', 'is_free', 'views_num', 'create_time', 'del_flag_x',
#        'praise_total', 'forward_total', 'comment_total', 'status', 'reason',
#        'updown_status', 'pic_width', 'pic_height', 'mark_id', 'power_type',
#        'resource_type', 'user_store_id', 'id_y', 'name_y', 'del_flag_y',
#        'is_enable'],
#       dtype='object')

# %%
fig = px.pie(artwork_g_category,names ='name_y')
#             title = 'Artwork Genre most popular with users',
#             hover_data = ['id_y','image_id'])
##fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>
#
#
#             <div id="bf767929-b774-4377-9ddc-4c5c70e478ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bf767929-b774-4377-9ddc-4c5c70e478ff")) {
#                     Plotly.newPlot(
#                         'bf767929-b774-4377-9ddc-4c5c70e478ff',
# ...

# %%
query_likes = "SELECT * FROM pframe_artwork_like;" 
df_likes = pd.read_sql(query_likes, mydb)
        #print(df.head())
daf_likes=pd.DataFrame(df_likes)

# %%
#daf_likes[]
len(daf_likes[(daf_likes['create_time'] > "2021-01-01") & (daf_likes['create_time'] < "2021-12-30")])
# Out:
# 2

# %%
daf_likes[(daf_likes['create_time'] > "2021-01-01") & (daf_likes['create_time'] < "2021-12-30")]
# Out:
#                     id                           user_id  \
# 0  1462695258570969090               1460432812046774274
# 1  1462695258570969091  91decac68377427281b8df2375015fac
#
#                          artwork_id         create_time
# 0  91decac68377427281b8df2375015fbb 2021-11-22 16:11:40
# 1  91decac68377427281b8df2375015fbb 2021-11-26 11:22:39

# %%
start_date = "2021-12-3"
#input(start_date:"")

# %%
("%s" % start_date)
# Out:
# '2021-12-3'

# %%
start_date
# Out:
# '2021-12-3'

# %%
query_shares = "SELECT * FROM pframe_artwork_share;" 
df_shares = pd.read_sql(query_shares, mydb)
        #print(df.head())
daf_shares=pd.DataFrame(df_shares)

# %%
share_art=daf_shares.merge(daf_query_artwork, how='inner', left_on='artwork_id', right_on='id')

# %%
share_art.columns
# Out:
# Index(['id_x', 'user_id_x', 'artwork_id', 'create_time_x', 'id_y', 'user_id_y',
#        'artist_id', 'artwork_category_id', 'type', 'name', 'pic_url',
#        'cost_price', 'price', 'stock', 'display_type', 'author', 'introduce',
#        'is_free', 'views_num', 'create_time_y', 'del_flag', 'praise_total',
#        'forward_total', 'comment_total', 'status', 'reason', 'updown_status',
#        'pic_width', 'pic_height', 'mark_id', 'power_type', 'resource_type',
#        'user_store_id'],
#       dtype='object')

# %%
fig = px.pie(share_art,names ='name')
#             title = 'Artwork Genre most popular with users',
#             hover_data = ['id_y','image_id'])
##fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>
#
#
#             <div id="d2487cd1-dcaa-40ae-828a-c185534eb7db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d2487cd1-dcaa-40ae-828a-c185534eb7db")) {
#                     Plotly.newPlot(
#                         'd2487cd1-dcaa-40ae-828a-c185534eb7db',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{label}", "labels": ["\u5c71\u6c34\u4e4b\u95f4", "\u5c71\u6c34\u4e4b\u95f4", "\u5c71\u6c34\u4e4b\u95f4", "\u6d4b\u8bd5\u827a\u672f\u54c1111", "\u6d4b\u8bd5\u827a\u672f\u54c1111", "11111", "\u7ed9\u751f\u6d3b\u4e0a\u4e00\u8bfe", "\u4e91\u6de1\u98ce\u8f7b"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie"}],
# ...

# %%
#fig = px.pie(share_art,names ='name')
#             title = 'Artwork Genre most popular with users',
#             hover_data = ['id_y','image_id'])
##fig.update_traces(textposition='inside', textinfo='percent+label')
#fig.show()
#sample data to play around with
fig = px.sunburst(share_art, path=['views_num','name','praise_total'], values='id_x', color='price')
fig.show()
# Out:
# <div>
#
#
#             <div id="c1028c88-332d-49db-9bb6-99635b6878bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1028c88-332d-49db-9bb6-99635b6878bc")) {
#                     Plotly.newPlot(
#                         'c1028c88-332d-49db-9bb6-99635b6878bc',
# ...

# %%
# function to retrieve the most similar products for a given one
import os
import shutil
from keras.preprocessing.image import load_img,img_to_array
from PIL import Image
import os
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

#from main_co import*


imgs_path = "M:/VieApp/images/images/"
imgs_model_width, imgs_model_height = 224, 224
nb_closest_images = 5

files = [imgs_path + x for x in os.listdir(imgs_path) if "jpg" in x]

def retrieve_most_similar_products(given_img):
    # compute cosine similarities between images
    imgs_features=np.load('images_feature.npy')
    cosSimilarities = cosine_similarity(imgs_features)
    
    # store the results into a pandas dataframe
    
    cos_similarities_df = pd.DataFrame(cosSimilarities, columns=files, index=files)
    

    print("--"*5)
    print("original product:")

    original = load_img(given_img, target_size=(imgs_model_width, imgs_model_height))
    #plt.imshow(original)
    #plt.show()

    print("-----------------------------------------------------------------------")
    print("most similar products:")

    #closest_imgs = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+1].index
    #closest_imgs_scores = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+1]
    #print(cos_similarities_df[given_img].sort_values(ascending=False))

    closest_imgs = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+26].index
    #print(closest_imgs)
    closest_imgs_scores = cos_similarities_df[given_img].sort_values(ascending=False)[1:nb_closest_images+26]
   
    destination_folder = 'C:/Users/CON3ADOLEA/Downloads/GNN-RecSys-main/recommenders-main/bio_dataset/'
    

    for i in range(0,len(closest_imgs)):
        original = load_img(closest_imgs[i], target_size=(imgs_model_width, imgs_model_height))
        #plt.imshow(original)
        #plt.show()
        print(closest_imgs[i])
        if closest_imgs[i]:
            shutil.copy(closest_imgs[i],destination_folder) ## use to copy files into a folder
                      
        print("similarity score : ",closest_imgs_scores[i])
    
    
retrieve_most_similar_products('M:/VieApp/images/images/A16PennsylvaniaDrawingRoom.jpg')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 261
# ----------
# original product:
# -----------------------------------------------------------------------
# most similar products:
# M:/VieApp/images/images/Cabinet187880.jpg
# similarity score :  0.97814786
# M:/VieApp/images/images/A12CapeCodLivingRoom175.jpg
# similarity score :  0.9759277
# M:/VieApp/images/images/A15NewYorkParlor185070.jpg
# similarity score :  0.9758113
# M:/VieApp/images/images/A8MassachusettsBedroomc.jpg
# similarity score :  0.9745785
# M:/VieApp/images/images/E4EnglishDrawingRoomoft.jpg
# similarity score :  0.9735812
# M:/VieApp/images/images/A14PennsylvaniaDrawingRoom.jpg
# similarity score :  0.9674145
# M:/VieApp/images/images/AltarpiecewithAdornedBuddha.jpg
# similarity score :  0.96661323
# M:/VieApp/images/images/E17FrenchBedroomLate16t.jpg
# similarity score :  0.9661512
# M:/VieApp/images/images/E3EnglishReceptionRoomof.jpg
# ...

# %%
# Import the libraries
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model
from pathlib import Path
from PIL import Image
class FeatureExtractor:
    def __init__(self):
        # Use VGG-16 as the architecture and ImageNet for the weight
        base_model = VGG16(weights='imagenet')
        # Customize the model to return features from fully-connected layer
        self.model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)
    def extract(self, img):
        # Resize the image
        img = img.resize((224, 224))
        # Convert the image color space
        img = img.convert('RGB')
        # Reformat the image
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        # Extract Features
        feature = self.model.predict(x)[0]
        return feature / np.linalg.norm(feature)
# Iterate through images (Change the path based on your image location)
for img_path in sorted("<IMAGE DATABASE PATH LIST HERE>"):
    print(img_path)
    # Extract Features
    feature = fe.extract(img=Image.open(img_path))
    # Save the Numpy array (.npy) on designated path
    feature_path = "<IMAGE FEATURE PATH HERE>.npy"
    np.save(feature_path, feature)
# Import the libraries
import matplotlib.pyplot as plt
import numpy as np
# Insert the image query
img = Image.open("<IMAGE QUERY PATH HERE>")
# Extract its features
query = fe.extract(img)
# Calculate the similarity (distance) between images
dists = np.linalg.norm(features - query, axis=1)
# Extract 30 images that have lowest distance
ids = np.argsort(dists)[:30]
scores = [(dists[id], img_paths[id]) for id in ids]
# Visualize the result
axes=[]
fig=plt.figure(figsize=(8,8))
for a in range(5*6):
    score = scores[a]
    axes.append(fig.add_subplot(5, 6, a+1))
    subplot_title=str(score[0])
    axes[-1].set_title(subplot_title)  
    plt.axis('off')
    plt.imshow(Image.open(score[1]))
fig.tight_layout()
plt.show()
