# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
import selenium
from selenium import webdriver

# %%
import os
import selenium
from selenium import webdriver
import time
from PIL import Image
import io
import requests
#from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import ElementClickInterceptedException

# %%
#DRIVER_PATH = 'C:/Users/CON3ADOLEA/Desktop/chromedriver_win32/chromedriver.exe'
#wb = webdriver.Chrome(executable_path=DRIVER_PATH)

# %%
#wb.get('https://www.artic.edu/collection?is_public_domain=1&department_ids=Modern%20Art')
#wb.get('https://www.artic.edu/artworks/109819/lozenge-composition-with-yellow-black-blue-red-and-gray')

# %%
#all_links = wb.find_elements_by_tag_name('a')
#all_links = wb.find_element_by_xpath('//li[@class="m-listing m-listing--variable-height o-pinboard__item s-positioned"]')

# %%
#wb.quit()

# %%
#import re
#import requests
#from bs4 import BeautifulSoup

#site = 'https://www.artic.edu/collection?is_public_domain=1&department_ids=Modern%20Art'

#response = requests.get(site)

#soup = BeautifulSoup(response.text, 'html.parser')
#img_tags = soup.find_all('img')

#urls = [img['src'] for img in img_tags]
#print(img_tags)

"""for url in urls:
    filename = re.search(r'/([\w_-]+[.](jpg|gif|png))$', url)
    if not filename:
         print("Regex didn't match with the url: {}".format(url))
         continue
    with open(filename.group(1), 'wb') as f:
        if 'http' not in url:
            # sometimes an image source can be relative 
            # if it is provide the base url which also happens 
            # to be the site variable atm. 
            url = '{}{}'.format(site, url)
        response = requests.get(url)
        f.write(response.content)"""
# Out:
# 'for url in urls:\n    filename = re.search(r\'/([\\w_-]+[.](jpg|gif|png))$\', url)\n    if not filename:\n         print("Regex didn\'t match with the url: {}".format(url))\n         continue\n    with open(filename.group(1), \'wb\') as f:\n        if \'http\' not in url:\n            # sometimes an image source can be relative \n            # if it is provide the base url which also happens \n            # to be the site variable atm. \n            url = \'{}{}\'.format(site, url)\n        response = requests.get(url)\n        f.write(response.content)'

# %%
#import pandas as pd
#from bs4 import BeautifulSoup
#from selenium import webdriver
#DRIVER_PATH = 'C:/Users/CON3ADOLEA/Desktop/chromedriver_win32/chromedriver.exe'
#driver = webdriver.Chrome(executable_path=DRIVER_PATH)
#driver.get('https://www.artic.edu/collection?is_public_domain=1&department_ids=Modern%20Art')
#results = []
#content = driver.page_source
#soup = BeautifulSoup(content)

# %%
#import library requests to send HTTP requests
import requests
for b in results:
#add the content of the url to a variable
    image_content = requests.get(b).content

# %%
import requests 
from bs4 import BeautifulSoup 
    
def getdata(url): 
    r = requests.get(url) 
    return r.text 
    
htmldata = getdata("https://www.artic.edu/collection?is_public_domain=1&department_ids=Modern%20Art") 
soup = BeautifulSoup(htmldata, 'html.parser') 
#for item in soup.find_all('img'):
#    print([item['data-pin-media']])
    #items=[item['data-pin-media']
#for item_t in soup.find_all('span'):
    #print(item_t)

# %%
import requests 
from bs4 import BeautifulSoup 
    
def getdata(url): 
    r = requests.get(url) 
    return r.text 
    
htmldata = getdata("https://www.artic.edu/artworks/8991/improvisation-no-30-cannons") 
soup = BeautifulSoup(htmldata, 'html.parser') 
#print(soup.prettify())

# %%
#list(soup.children) # use to pritn out the keys in the html

# %%
#soup

# %%
soup.find_all('p')
# Out:
# [<p class="title f-secondary o-article__inline-header-display">1913</p>,
#  <p class="title f-secondary o-article__inline-header-display">Vasily Kandinsky<br/>French, born Russia, 1866–1944</p>,
#  <p>In his seminal 1912 text <em>Concerning the Spiritual in Art</em>, Vasily Kandinsky advocated an art that could move beyond imitation of the physical world, inspiring, as he put it, “vibrations in the soul.” Pioneering abstraction as the richest, most musical form of artistic expression, Kandinsky believed that the physical properties of artworks could stir emotions, and he produced a revolutionary group of increasingly abstract canvases—with titles such as <em>Fugue, Impression</em>, and <em>Improvisation</em>—hoping to bring painting closer to music making.</p>,
#  <p>Kandinsky’s paintings are, in his words, “largely unconscious, spontaneous expressions of inner character, nonmaterial in nature.” Although <em>Improvisation No. 30 (Cannons)</em> at first appears to be an almost random assortment of brilliant colors, shapes, and lines, the artist also included leaning buildings, a crowd of people, and a wheeled, smoking cannon. In a letter to the Chicago lawyer Arthur Jerome Eddy, who purchased the painting in 1913 and later bequeathed it to the Art Institute, Kandinsky explained that “the presence of the cannons in the picture could probably be explained by the constant war talk that has been going on throughout the year.” Eventually, Kandinsky ceased making these references to the material world in his work and wholly devoted himself to pure abstraction.</p>,
#  <p>Arthur Jerome Eddy (1859-1920), Chicago, probably purchased from the artist, by 1920; by descent to his wife Lucy O. Eddy (1863-1931) and son Jerome O. Eddy (1891-1951), Chicago, 1920; given to the Art Institute of Chicago, 1931.</p>,
#  <p class="f-caption">Object information is a work in progress and may be updated as new research findings emerge. To help improve this record, please email <a data-behavior="maskEmail" data-maskemail-domain="artic.edu" data-maskemail-user="collections"></a>. Information about image downloads and licensing is <a href="/image-licensing">available here</a>.</p>]

# %%
a=list(soup.find_all('p'))
a[3].get_text()
# Out:
# 'Kandinsky’s paintings are, in his words, “largely unconscious, spontaneous expressions of inner character, nonmaterial in nature.” Although Improvisation No. 30 (Cannons) at first appears to be an almost random assortment of brilliant colors, shapes, and lines, the artist also included leaning buildings, a crowd of people, and a wheeled, smoking cannon. In a letter to the Chicago lawyer Arthur Jerome Eddy, who purchased the painting in 1913 and later bequeathed it to the Art Institute, Kandinsky explained that “the presence of the cannons in the picture could probably be explained by the constant war talk that has been going on throughout the year.” Eventually, Kandinsky ceased making these references to the material world in his work and wholly devoted himself to pure abstraction.'

# %%
list(soup.find_all('p', class_='title f-secondary o-article__inline-header-display')) #display authors name
for i in list(soup.find_all('p', class_='title f-secondary o-article__inline-header-display')):
    print(i.get_text())
# Out:
# 1913
# Vasily KandinskyFrench, born Russia, 1866–1944

# %%
#list(soup.find_all('p'))[2:]
#for i in list(soup.find_all('p'))[2:]:
#    #print(i.get_text())
#    print(i)

# %%
for item_t in soup.find_all('div',class_="o-blocks"):
    #for i in [item_t.find_all('p')[0:][:-2]]:
    #    print(i[0:])
    for i in list([item_t.find_all('p')[0:][:-2]]):
        if i == []:
            [x for x in i if x]
        else:
            print(i)
# Out:
# [<p>In his seminal 1912 text <em>Concerning the Spiritual in Art</em>, Vasily Kandinsky advocated an art that could move beyond imitation of the physical world, inspiring, as he put it, “vibrations in the soul.” Pioneering abstraction as the richest, most musical form of artistic expression, Kandinsky believed that the physical properties of artworks could stir emotions, and he produced a revolutionary group of increasingly abstract canvases—with titles such as <em>Fugue, Impression</em>, and <em>Improvisation</em>—hoping to bring painting closer to music making.</p>, <p>Kandinsky’s paintings are, in his words, “largely unconscious, spontaneous expressions of inner character, nonmaterial in nature.” Although <em>Improvisation No. 30 (Cannons)</em> at first appears to be an almost random assortment of brilliant colors, shapes, and lines, the artist also included leaning buildings, a crowd of people, and a wheeled, smoking cannon. In a letter to the Chicago lawyer Arthur Jerome Eddy, who purchased the painting in 1913 and later bequeathed it to the Art Institute, Kandinsky explained that “the presence of the cannons in the picture could probably be explained by the constant war talk that has been going on throughout the year.” Eventually, Kandinsky ceased making these references to the material world in his work and wholly devoted himself to pure abstraction.</p>]

# %%
htmlda = getdata("https://www.artic.edu/collection?is_public_domain=1&department_ids=Modern%20Art") 
sou = BeautifulSoup(htmlda, 'html.parser')

# %%
d=sou.find_all("span")

# %%
for item_t in soup.find_all('dl', class_="deflist o-blocks__block"):
    for nex in item_t.find_all('dd'):
        print(nex.get_text())
# Out:
# Vasily Kandinsky
#
#
#
# Improvisation No. 30 (Cannons)
#
#
# Germany
#
#
#
#  1913
#
#
#
# Oil on canvas
#
#
# signed, l.l.: “Kandsky i9i3”
#
#
# 111 × 111.3 cm (43 11/16 × 43 13/16 in.)
#
#
# Arthur Jerome Eddy Memorial Collection
#
#
# 1931.511
#
#
# https://api.artic.edu/api/v1/artworks/8991/manifest.json

# %%
d=[]
for item_t in soup.find_all('dl', class_="deflist o-blocks__block"):
    for nex in list(item_t.find_all('dd')[6]):
        #print(nex.get_text())
        if nex == '\n':
            [x for x in nex if x]
        else:
            #d=[]
            print(nex.get_text())
            #d.append(nex.get_text())
            #new_items = [x[1:] for x in d]
            #new_ite = [x[:-1] for x in new_items]
            #print(new_ite)
            #d.append(new_ite)
# Out:
# 111 × 111.3 cm (43 11/16 × 43 13/16 in.)

# %%
d
# Out:
# ['111 × 111.3 cm (43 11/16 × 43 13/16 in.)',
#  ['11 × 111.3 cm (43 11/16 × 43 13/16 in.']]

# %%
for it in d:
   # print(it)
    for a in it:
        for im in sou.find_all('li', class_='m-listing m-listing--variable-height o-pinboard__item s-positioned'):
            print(im)

# %%
ef =sou.find_all('a', class_="m-listing__link")
for c in ef:
    for s in c:
        for g in s:
            #print(sou.find_all('img'))#class_="data-pin-media"))
# Out:
#   File "<ipython-input-266-69157e9e9ad9>", line 5
#     #print(sou.find_all('img'))#class_="data-pin-media"))
#                                                          ^
# SyntaxError: unexpected EOF while parsing

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import pandas as pd

html = urlopen('https://www.artic.edu/collection?is_public_domain=1&department_ids=Modern%20Art')
bs = BeautifulSoup(html, 'html.parser')
images = bs.find_all('img', {'data-pin-media':re.compile('.jpg')})
#for image in images: 
#    print((image['data-pin-media']+'\n'))

# %%
import requests 
from bs4 import BeautifulSoup 
import re
import pandas as pd

def getdata(url): 
    r = requests.get(url) 
    return r.text
htmldata = getdata("https://www.artic.edu/collection?department_ids=Painting%20and%20Sculpture%20of%20Europe&is_public_domain=1&page=2")#https://www.artic.edu/collection?is_public_domain=1&department_ids=Modern%20Art 
soup = BeautifulSoup(htmldata, 'html.parser')
_links=[]
tit_link=[]
aut=[]
        
for all_title in soup.find_all('strong', class_="title f-list-7"):
    tit=all_title.get_text() ##provides the title of the art work in image_url
    tit_link.append(tit)
    
for all_links in soup.find_all('a',class_="m-listing__link"):
    links=(all_links['href']) ##provide link to webpage for each item
    _links.append(links)
    for items in _links:
        cont_page = requests.get(items)
        htmls = cont_page.content
        soup_link = BeautifulSoup(htmls,"html.parser")
        for item_t in list(soup_link.find_all('p',class_="title f-secondary o-article__inline-header-display")):
            desx=item_t.get_text()
            aut.append(desx)
            
dimension = [] #dimension of the artwork
date_created =[] #date artwork was created
artwork_origin =[] #artwork origin
medium = [] #artwork medium
decript_aut=[]#details about author

artwork_artist=[] #artist name
artwork_dept=[] #artwork department
title_artwork=[] # artwork title
date_released=[] # date artwork was released
aut_life=[] #authors name and time lived


for all_links in _links:
    cont_page= requests.get(all_links)
    htmls = cont_page.content
    sou= BeautifulSoup(htmls,"html.parser")
    for item_t in sou.find_all('p',class_="title f-secondary o-article__inline-header-display")[:-1]:
        datx=(item_t.get_text()) ## obtain date artwork was released
        date_released.append(datx)
        
    for item_t in sou.find_all('p',class_="title f-secondary o-article__inline-header-display")[1:]:
        daty=(item_t.get_text()) ##obtain author life on earth
        aut_life.append(daty)
        
    for item_t in sou.find_all('span', class_ ="title f-headline-editorial o-article__inline-header-title"):
        title_artwork.append(item_t.get_text()) ##artwork title
        
    for item_t in sou.find_all('ul', class_="list list--inline f-secondary"):        
        artwork_dept.append(item_t.get_text()) ## artwork department
        
    for item_t in sou.find_all('div',class_="o-blocks"):
        for i in list([item_t.find_all('p')[0:][:-2]]):
            if i == []:
                [x for x in i if x]
            else:
                decript_aut.append(i)
    
    for item_t in sou.find_all('dl', class_="deflist o-blocks__block"):
        for nex in item_t.find_all('dd')[0]:
            #print(nex.get_text())
            if nex == '\n':
                [x for x in nex if x]
            else:
                d=[]
                d.append(nex.get_text())
                rem_n1 = [x[1:] for x in d]
                rem_n = [x[:-1] for x in rem_n1]
                artwork_artist.append(rem_n) ### artist name
        
        for n in item_t.find_all('dd')[2]:
            if n == '\n':
                [x for x in n if x]
            else:
                artwork_origin.append(n.get_text()) ##artwork origin
        
        for e in item_t.find_all('dd')[3]:
            #print(nex.get_text())
            if e == '\n':
                [x for x in e if x]
            else:
                c=[]
                c.append(e.get_text())
                rem_n1 = [x[1:] for x in c]
                rem_n = [x[:-1] for x in rem_n1]
                date_created.append(rem_n) ### date artwork was created
                
        for cex in item_t.find_all('dd')[4]:
            if cex == '\n':
                [x for x in cex if x]
            else:
                medium.append(cex.get_text()) ##artwork medium
        
        for cx in item_t.find_all('dd')[5]:
            if cx == '\n':
                [x for x in cx if x]
            else:
                dimension.append(cx.get_text()) ##artwork dimension

# %%
"""this stores the values in all pages"""
from bs4 import BeautifulSoup as bs
from bs4 import BeautifulSoup
import requests
import urllib.request
import shutil
import random
import re
import pandas as pd

page = 8
title = []
_links=[]
im_link =[]
image_info = []

dimension = [] #dimension of the artwork
date_created =[] #date artwork was created
artwork_origin =[] #artwork origin
medium = [] #artwork medium
decript_aut=[]#details about author
artwork_artist=[] #artist name
artwork_dept=[] #artwork department
title_artwork=[] # artwork title
date_released=[] # date artwork was released
aut_life=[] #authors name and time lived

def getdata(url): 
    r = requests.get(url) 
    return r.text

while page != 16:
    url = f"https://www.artic.edu/collection?is_public_domain=1&page={page}"
    #print(url)
    response = requests.get(url)
    html = response.content
    soup = bs(html, "html.parser")
        
    for all_title in soup.find_all('strong', class_="title f-list-7"):
        tit=all_title.get_text() ##provides the title of the art work in image_url
        title.append(tit)
    
    for a in soup.find_all('a',class_="m-listing__link"):
        image_tag = a.findChildren("img")
        image_tilt=a.findChildren("strong",class_="title f-list-7")
        for i in image_tilt:
            v=random.randint(3, 9)
            if i == None:
                print(i.append(v))
            else:
                #image_info.append(i.get_text())
                for c in image_tag:
                    cd=c["data-pin-media"]
                    z=(cd,i.get_text())
                    image_info.append(z)
            
    for item_t in soup.find_all('span'):
        images = item_t.find_all('img', {'data-pin-media':re.compile('.jpg')})
        for image in images:
            image_url=((image['data-pin-media']+'\n')) #provides the image link to download with 600 size
            im_link.append(image_url)
        #print(image_url)
    
#    def download_image(image_info):
#        response = requests.get(image_info[0], stream=True)
#        realname = ''.join(e for e in image_info[1] if e.isalnum())
#        file = open("./10000/{}.jpg".format(realname), 'wb')
#        response.raw.decode_content = True
#        shutil.copyfileobj(response.raw, file)
#        del response
    
    
    
    for all_links in soup.find_all('a',class_="m-listing__link"):
        links=(all_links['href']) ##provide link to webpage for each item
        _links.append(links)
    #print(_links)
    
    for all_link in _links:
        cont_page= requests.get(all_link)
        htmls = cont_page.content
        sou= BeautifulSoup(htmls,"html.parser")
        for item_t in sou.find_all('p',class_="title f-secondary o-article__inline-header-display")[:-1]:
            datx=(item_t.get_text()) ## obtain date artwork was released
            date_released.append(datx)
        
        for item_t in sou.find_all('p',class_="title f-secondary o-article__inline-header-display")[1:]:
            daty=(item_t.get_text()) ##obtain author life on earth
            aut_life.append(daty)
        
        for item_t in sou.find_all('span', class_ ="title f-headline-editorial o-article__inline-header-title"):
            title_artwork.append(item_t.get_text()) ##artwork title
        
        for item_t in sou.find_all('ul', class_="list list--inline f-secondary"):        
            artwork_dept.append(item_t.get_text()) ## artwork department
        
#        for item_t in sou.find_all('div',class_="o-blocks"):
#            for i in list([item_t.find_all('p')[0:][:-2]]):
#                if i == []:
#                    [x for x in i if x]
#                else:
#                    decript_aut.append(i)
                        
        for item_t in sou.find_all('dl', class_="deflist o-blocks__block"):
            for nex in item_t.find_all('dd')[0]:
                #print(nex.get_text())
                if nex == '\n':
                    [x for x in nex if x]
                else:
                    d=[]
                    d.append(nex.get_text())
                    rem_n1 = [x[1:] for x in d]
                    rem_n = [x[:-1] for x in rem_n1]
                    artwork_artist.append(rem_n) ### artist name
                        
            for n in item_t.find_all('dd')[2]:
                if n == '\n':
                    [x for x in n if x]
                else:
                    artwork_origin.append(n.get_text()) ##artwork origin
                        
            for e in item_t.find_all('dd')[3]:
                #print(nex.get_text())
                if e == '\n':
                    [x for x in e if x]
                else:
                    c=[]
                    c.append(e.get_text())
                    rem_n1 = [x[1:] for x in c]
                    rem_n = [x[:-1] for x in rem_n1]
                    date_created.append(rem_n) ### date artwork was created
                
            for cex in item_t.find_all('dd')[4]:
                if cex == '\n':
                    [x for x in cex if x]
                else:
                    medium.append(cex.get_text()) ##artwork medium
                        
            for cx in item_t.find_all('dd')[5]:
                if cx == '\n':
                    [x for x in cx if x]
                else:
                    dimension.append(cx.get_text()) ##artwork dimension
        
        
    page = page + 1
    
    
#f=(title,artwork_artist,im_link,_links,title_artwork,
#   date_released,aut_life,artwork_dept,dimension,
#   date_created,artwork_origin,medium,decript_aut) ##merging the arrays
#print(f)
#df_ = pd.DataFrame(f,index = ["title","authors_name","image_link","image_webpage","artwork_title",
#                              "date_released","authors_name_and_age","artwork_department","dimension",
#                             "date_created","artwork_origin","artwork_medium","artwork_description"])#
f=(title,artwork_artist,title_artwork,date_released,aut_life,artwork_dept,dimension,date_created,artwork_origin,medium,image_info)
df_ = pd.DataFrame(f,index = ["title","authors_name",
                              "artwork_title","date_released",
                              "authors_name_and_age","artwork_department",
                              "dimension","date_created","artwork_origin",
                              "artwork_medium","image_information"])


dataset=pd.DataFrame(df_.T)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-497-25c99c7fe28e> in <module>
#     137                     medium.append(cex.get_text()) ##artwork medium
#     138
# --> 139             for cx in item_t.find_all('dd')[5]:
#     140                 if cx == '\n':
#     141                     [x for x in cx if x]
#
# IndexError: list index out of range

# %%
len(date_created)

# %%
for i in range(0, len(image_info)):
    download_image(image_info[i])

# %%
data_set
# Out:
#                                                  title  \
# 0                                    The Bedroom, 1889
# 1    Buddha Shakyamuni Seated in Meditation (Dhyana...
# 2                        Paris Street; Rainy Day, 1877
# 3          A Sunday on La Grande Jatte — 1884, 1884/86
# 4    Coronation Stone of Motecuhzoma II (Stone of t...
# ..                                                 ...
# 455                                               None
# 456                                               None
# 457                                               None
# 458                                               None
# 459                                               None
#
#                                           authors_name  \
# 0                                   [Vincent van Gogh]
# 1    [uddha Shakyamuni Seated in Meditation (Dhyana...
# 2                                [Gustave Caillebotte]
# 3                                     [Georges Seurat]
# 4                                     [Aztec (Mexica)]
# ..                                                 ...
# 455                                   [Albrecht Dürer]
# 456                           [Joseph Wright of Derby]
# 457                     [Jean Baptiste Siméon Chardin]
# 458                                 [Carleton Watkins]
# 459                               [Rembrandt van Rijn]
#
#                                          artwork_title  \
# 0                                          The Bedroom
# 1    Buddha Shakyamuni Seated in Meditation (Dhyana...
# 2                              Paris Street; Rainy Day
# 3                   A Sunday on La Grande Jatte — 1884
# 4    Coronation Stone of Motecuhzoma II (Stone of t...
# ..                                                 ...
# 455                                         Young Bull
# 456                         Self-Portrait in a Fur Cap
# 457                         Self-Portrait with a Visor
# 458  Big River, from the Rancherie, Mendocino, Cali...
# 459                                 Seated Female Nude
#
#                                          date_released  \
# 0                                                 1889
# 1       Chola period (c. 855-1279), about 12th century
# 2                                                 1877
# 3                                              1884/86
# 4                                                 1503
# ..                                                 ...
# 455  c. 1496, erroneously inscribed in another hand...
# 456                                            1765/68
# 457                                            c. 1776
# 458                                               1863
# 459                                            1660/62
#
#                          authors_name_and_age  \
# 0            Vincent van GoghDutch, 1853-1890
# 1          IndiaTamil Nadu, near Nagapattinam
# 2     Gustave Caillebotte (French, 1848-1894)
# 3             Georges SeuratFrench, 1859-1891
# 4          Aztec (Mexica)Tenochtitlan, Mexico
# ..                                        ...
# 455           Albrecht DürerGerman, 1471–1528
# 456  Joseph Wright of DerbyEnglish, 1734-1797
# 457      Jean-Siméon ChardinFrench, 1699-1779
# 458       Carleton WatkinsAmerican, 1829–1916
# 459        Rembrandt van RijnDutch, 1606-1669
#
#                                     artwork_department  \
# 0    \nPainting and Sculpture of Europe\nGallery 241\n
# 1                        \nArts of Asia\nGallery 140\n
# 2    \nPainting and Sculpture of Europe\nGallery 201\n
# 3    \nPainting and Sculpture of Europe\nGallery 240\n
# 4                \nArts of the Americas\nGallery 136\n
# ..                                                 ...
# 455                            \nPrints and Drawings\n
# 456                            \nPrints and Drawings\n
# 457                            \nPrints and Drawings\n
# 458                          \nPhotography and Media\n
# 459                            \nPrints and Drawings\n
#
#                                              dimension  date_created  \
# 0                     73.6 × 92.3 cm (29 × 36 5/8 in.)       [ 1889]
# 1    Purchased with funds provided by Mr. and Mrs. ...       [ranit]
# 2        Inscribed at lower left: G. Caillebotte. 1877   [Made 1877]
# 3                     Inscribed at lower right: Seurat  [ 1884–1886]
# 4                55.9 × 66 × 22.9 cm (22 × 26 × 9 in.)   [Made 1503]
# ..                                                 ...           ...
# 455                                       175 × 140 mm       [ 1508]
# 456                                         Not signed  [ 1765–1768]
# 457                                       457 × 374 mm  [ 1771–1781]
# 458  Printed recto, on mount, below image, lower ce...   [Made 1863]
# 459          212 × 175 mm (primary/secondary supports)  [ 1660–1662]
#
#                                         artwork_origin  \
# 0              Saint-Rémy-de-Provence (Object made in)
# 1                                       \n 1101–1200\n
# 2                               Paris (Object made in)
# 3                              France (Object made in)
# 4    Tenochtitlan (Object made in), Valley of Mexic...
# ..                                                 ...
# 455                                            Germany
# 456                                            England
# 457                                             France
# 458                                      United States
# 459                                            Holland
#
#                                         artwork_medium image_information
# 0                                        Oil on canvas              None
# 1    160.0 × 120.2 × 56.3 cm (63 × 47 5/16 × 22 3/1...              None
# 2                                        Oil on canvas              None
# 3                                        Oil on canvas              None
# 4                                               Basalt              None
# ..                                                 ...               ...
# 455              Pen and black ink on ivory laid paper              None
# 456  Monochrome pastel (grisaille) on blue-gray lai...              None
# 457       Pastel on blue laid paper, mounted on canvas              None
# 458                                      Albumen print              None
# 459  Pen and brown ink and brush and brown wash, wi...              None
#
# [460 rows x 11 columns]

# %%
"""this stores the values in all pages"""
from bs4 import BeautifulSoup as bs
from bs4 import BeautifulSoup
import requests
import urllib.request
import shutil
import random
import re
import pandas as pd

page = 6
title = []
_links=[]
im_link =[]
image_info = []

dimension = [] #dimension of the artwork
date_created =[] #date artwork was created
artwork_origin =[] #artwork origin
medium = [] #artwork medium
decript_aut=[]#details about author
artwork_artist=[] #artist name
artwork_dept=[] #artwork department
title_artwork=[] # artwork title
date_released=[] # date artwork was released
aut_life=[] #authors name and time lived

def getdata(url): 
    r = requests.get(url) 
    return r.text

while page != 11:
    url = f"https://www.artic.edu/collection?is_public_domain=1&page={page}"
    #print(url)
    response = requests.get(url)
    html = response.content
    soup = bs(html, "html.parser")
        
    for all_title in soup.find_all('strong', class_="title f-list-7"):
        tit=all_title.get_text() ##provides the title of the art work in image_url
        title.append(tit)
    
    for a in soup.find_all('a',class_="m-listing__link"):
        image_tag = a.findChildren("img")
        image_tilt=a.findChildren("strong",class_="title f-list-7")
        
        for i in image_tilt:
            v=random.randint(3, 9)
            if i == None:
                print(i.append(v))
            else:
                #image_info.append(i.get_text())
                for c in image_tag:
                    cd=c["data-pin-media"]
                    z=(cd,i.get_text())
                    image_info.append(z)
        
#        for i in image_tilt:
#            v=random.randint(3, 9)
#            if i == None:
#                i.append(v)
#            else:
#                #image_info.append(i.get_text())
#                z=(image_tag[0]["data-pin-media"],i.get_text())
#            #print(image_tag[0]["data-pin-media"])
#            #print(image_info)
#            image_info.append(z)
            
    for item_t in soup.find_all('span'):
        images = item_t.find_all('img', {'data-pin-media':re.compile('.jpg')})
        for image in images:
            image_url=((image['data-pin-media']+'\n')) #provides the image link to download with 600 size
            im_link.append(image_url)
        #print(image_url)
    
    def download_image(image_info):
        response = requests.get(image_info[0], stream=True)
        realname = ''.join(e for e in image_info[1] if e.isalnum())
        file = open("./10000/{}.jpg".format(realname), 'wb')
        response.raw.decode_content = True
        shutil.copyfileobj(response.raw, file)
        del response
    
    
    
    for all_links in soup.find_all('a',class_="m-listing__link"):
        links=(all_links['href']) ##provide link to webpage for each item
        _links.append(links)
    #print(_links)
    
    for all_link in _links:
        cont_page= requests.get(all_link)
        htmls = cont_page.content
        sou= BeautifulSoup(htmls,"html.parser")
        for item_t in sou.find_all('p',class_="title f-secondary o-article__inline-header-display")[:-1]:
            datx=(item_t.get_text()) ## obtain date artwork was released
            date_released.append(datx)
        
        for item_t in sou.find_all('p',class_="title f-secondary o-article__inline-header-display")[1:]:
            daty=(item_t.get_text()) ##obtain author life on earth
            aut_life.append(daty)
        
        for item_t in sou.find_all('span', class_ ="title f-headline-editorial o-article__inline-header-title"):
            title_artwork.append(item_t.get_text()) ##artwork title
        
        for item_t in sou.find_all('ul', class_="list list--inline f-secondary"):        
            artwork_dept.append(item_t.get_text()) ## artwork department
        
        for item_t in sou.find_all('div',class_="o-blocks"):
            for i in list([item_t.find_all('p')[0:][:-2]]):
                if i == []:
                    [x for x in i if x]
                else:
                    decript_aut.append(i)
                        
        for item_t in sou.find_all('dl', class_="deflist o-blocks__block"):
            for nex in item_t.find_all('dd')[0]:
                #print(nex.get_text())
                if nex == '\n':
                    [x for x in nex if x]
                else:
                    d=[]
                    d.append(nex.get_text())
                    rem_n1 = [x[1:] for x in d]
                    rem_n = [x[:-1] for x in rem_n1]
                    artwork_artist.append(rem_n) ### artist name
                        
            for n in item_t.find_all('dd')[2]:
                if n == '\n':
                    [x for x in n if x]
                else:
                    artwork_origin.append(n.get_text()) ##artwork origin
                        
            for e in item_t.find_all('dd')[3]:
                #print(nex.get_text())
                if e == '\n':
                    [x for x in e if x]
                else:
                    c=[]
                    c.append(e.get_text())
                    rem_n1 = [x[1:] for x in c]
                    rem_n = [x[:-1] for x in rem_n1]
                    date_created.append(rem_n) ### date artwork was created
                
            for cex in item_t.find_all('dd')[4]:
                if cex == '\n':
                    [x for x in cex if x]
                else:
                    medium.append(cex.get_text()) ##artwork medium
                        
            for cx in item_t.find_all('dd')[5]:
                if cx == '\n':
                    [x for x in cx if x]
                else:
                    dimension.append(cx.get_text()) ##artwork dimension
        
        
    page = page + 1
    
    
#f=(title,artwork_artist,im_link,_links,title_artwork,
#   date_released,aut_life,artwork_dept,dimension,
#   date_created,artwork_origin,medium,decript_aut) ##merging the arrays
#print(f)
#df_ = pd.DataFrame(f,index = ["title","authors_name","image_link","image_webpage","artwork_title",
#                              "date_released","authors_name_and_age","artwork_department","dimension",
#                             "date_created","artwork_origin","artwork_medium","artwork_description"])#
f=(title,artwork_artist,title_artwork,date_released,aut_life,artwork_dept,dimension,date_created,artwork_origin,medium,image_info)
df_ = pd.DataFrame(f,index = ["title","authors_name",
                              "artwork_title","date_released",
                              "authors_name_and_age","artwork_department",
                              "dimension","date_created","artwork_origin",
                              "artwork_medium","image_information"])

dataset=pd.DataFrame(df_.T)

#for i in range(0, len(image_info)):
#    download_image(image_info[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-520-d424fd4575de> in <module>
#     149                     medium.append(cex.get_text()) ##artwork medium
#     150
# --> 151             for cx in item_t.find_all('dd')[5]:
#     152                 if cx == '\n':
#     153                     [x for x in cx if x]
#
# IndexError: list index out of range

# %%
len(dataset)

# %%
dataset.iloc[249]

# %%
dataset.to_csv("page_1_5.csv")

# %%
dataset

# %%
def download_image(image_info):
    response = requests.get(image_info[0], stream=True)
    realname = ''.join(e for e in image_info[1][:30] if e.isalnum())
    file = open("./images_bs/{}.jpg".format(realname), 'wb')
    response.raw.decode_content = True
    shutil.copyfileobj(response.raw, file)
    filenames.append(realname) ##names for the artwork
    del response

# %%
for i in range(0, len(image_info)):
    download_image(image_info[i])

# %%
import pandas as pd

df = pd.read_csv('ge.csv', encoding='utf-8')

print(df)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-f2d3c0eb2cb0> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('ge.csv', encoding='utf-8')
#       4
#       5 print(df)
#
# ~\.conda\envs\colour_recommendation\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~\.conda\envs\colour_recommendation\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~\.conda\envs\colour_recommendation\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~\.conda\envs\colour_recommendation\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~\.conda\envs\colour_recommendation\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x97 in position 1061: invalid start byte
